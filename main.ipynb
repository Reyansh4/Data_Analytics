# %% [markdown]
# #**India Crop Production - State wise**
#
# This is the present dataset i am working on and the link for the used dataset is https://data.world/thatzprem/agriculture-india
#
# Let's Begin the Data Wrangling in python.
#
# Let's begin by importing the required libraries

# %% [markdown]
# #**IMPORTING THE REQUIRED LIBRARIES**

# %%
import pandas as pd
import numpy as np
import missingno as msno

# %% [markdown]
# #**IMPORTING THE DATA**

# %%
data = pd.read_csv("crop_production.csv")
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %% [markdown]
# #**LET'S US UNDERSTAND OUR DATA**

# %%
print("The null values in each column are : \n", data.isna().sum())
# Out:
# The null values in each column are :
#  State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
print("The shape of the datasets is : ", data.shape)
print("The no of rows in the data are : ", data.shape[0])
print("The no of columns in the dataset are : ", data.shape[1])
# Out:
# The shape of the datasets is :  (246091, 7)
# The no of rows in the data are :  246091
# The no of columns in the dataset are :  7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
data.describe(include="all")
# Out:
#            State_Name District_Name      Crop_Year       Season    Crop  \
# count          246091        246091  246091.000000       246091  246091
# unique             33           646            NaN            6     124
# top     Uttar Pradesh       BIJAPUR            NaN  Kharif         Rice
# freq            33306           945            NaN        95951   15104
# mean              NaN           NaN    2005.643018          NaN     NaN
# std               NaN           NaN       4.952164          NaN     NaN
# min               NaN           NaN    1997.000000          NaN     NaN
# 25%               NaN           NaN    2002.000000          NaN     NaN
# 50%               NaN           NaN    2006.000000          NaN     NaN
# 75%               NaN           NaN    2010.000000          NaN     NaN
# max               NaN           NaN    2015.000000          NaN     NaN
#
#                 Area    Production
# count   2.460910e+05  2.423610e+05
# ...

# %%
msno.matrix(data)
# Out:
# <AxesSubplot: >

# %%
for col_names in data.columns:
    print(col_names)
# Out:
# State_Name
# District_Name
# Crop_Year
# Season
# Crop
# Area
# Production

# %%
print("The unique elements in the column State_Name are : ", len(data['State_Name'].value_counts().sort_values(ascending=False)))
print("The unique elements in the column District_Name are : ", len(data['District_Name'].value_counts().sort_values(ascending=False)))
print("The unique elements in the column Crop_Year are : ", len(data['Crop_Year'].value_counts().sort_values(ascending=False)))
print("The unique elements in the column Season are : ", len(data['Season'].value_counts().sort_values(ascending=False)))
print("The unique elements in the column Crop are : ", len(data['Crop'].value_counts().sort_values(ascending=False)))
# Out:
# The unique elements in the column State_Name are :  33
# The unique elements in the column District_Name are :  646
# The unique elements in the column Crop_Year are :  19
# The unique elements in the column Season are :  6
# The unique elements in the column Crop are :  124

# %% [markdown]
# Lets Do preprocessing and make a new csv for Data Visualization in Tableau.

# %%
data = data.dropna()
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
#lets see for null values in the pandas again
print(data.isna().sum())
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
#lets drop duplicate values in the pandas
data = data.drop_duplicates()
data
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
msno.matrix(data)
# Out:
# <AxesSubplot: >

# %%
crop_counts = data.groupby('Crop')['Crop_Year'].nunique()

crops_harvested_every_year = crop_counts[crop_counts == data['Crop_Year'].nunique()].index

new_data = data[data['Crop'].isin(crops_harvested_every_year)]
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 7       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 11      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 12      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 1       Other Kharif pulses       2.0         1.0
# ...

# %%
print("The shape of the datasets is : ", new_data.shape)
print("The no of rows in the data are : ", new_data.shape[0])
print("The no of columns in the dataset are : ", new_data.shape[1])
# Out:
# The shape of the datasets is :  (121214, 7)
# The no of rows in the data are :  121214
# The no of columns in the dataset are :  7

# %%
new_data.to_csv("result.csv", index=False)
